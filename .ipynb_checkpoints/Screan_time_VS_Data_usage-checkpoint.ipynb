# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Screen_time_vs_Data_usage.csv')
df
# Out:
#     Screen_Time  Data_usage
# 0          4.03        0.98
# 1          6.05        2.18
# 2          6.08        3.63
# 3          2.44        1.06
# 4          4.53        8.56
# 5          5.52        3.57
# 6          8.36        1.96
# 7          3.50        1.89
# 8          4.43        3.18
# 9          3.17        0.75
# 10         2.44        0.53
# 11         5.24        5.67
# 12         3.54        1.66
# 13         5.44        1.47
# 14         5.44        2.71
# 15         5.04        3.65
# 16         2.58        1.18
# 17         5.03        1.00
# 18         4.30        2.95
# 19         7.33        2.21
# 20         5.56        4.46
# 21         3.29        0.83
# 22         2.48        0.81
# 23         3.41        1.38
# 24         4.23        1.40
# 25         6.04        1.27
# 26         7.03        9.65

# %%
plt.scatter(x=df['Screen_Time'],y=df['Data_usage'])
