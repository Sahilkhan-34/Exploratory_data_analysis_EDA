# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Donor

# %%
df = pd.read_excel(r'C:\Users\sahil\Downloads\doner.xlsx')

# %%
df.head(150)
# Out:
#      Sr No.      Reference No  (URN)         Journal Date  \
# 0         1  00001201904120000001166  2019-04-12 00:00:00
# 1         2  00001201904120000001166  2019-04-12 00:00:00
# 2         3  00001201904120000001166  2019-04-12 00:00:00
# 3         4  00001201904120000001166  2019-04-12 00:00:00
# 4         5  00001201904120000001166  2019-04-12 00:00:00
# ..      ...                      ...                  ...
# 145     144  00847201904120000001164  2019-04-12 00:00:00
# 146     145  00847201904120000001164  2019-04-12 00:00:00
# 147     146  00847201904120000001164  2019-04-12 00:00:00
# 148     147  00847201904120000001164  2019-04-12 00:00:00
# 149  Sr No.      Reference No  (URN)         Journal Date
#
#        Date of\nPurchase       Date of Expiry  \
# 0    2019-04-12 00:00:00  2019-04-26 00:00:00
# 1    2019-04-12 00:00:00  2019-04-26 00:00:00
# 2    2019-04-12 00:00:00  2019-04-26 00:00:00
# 3    2019-04-12 00:00:00  2019-04-26 00:00:00
# ...

# %%
df.shape
# Out:
# (19256, 12)

# %%
index = [x for x in range(49,19257,50)]
#print(index) # to check index

# %%
df.drop(index, inplace=True)

# %%
df.head(150)
# Out:
#     Sr No.      Reference No  (URN)         Journal Date    Date of\nPurchase  \
# 0        1  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 1        2  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 2        3  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 3        4  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 4        5  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# ..     ...                      ...                  ...                  ...
# 147    146  00847201904120000001164  2019-04-12 00:00:00  2019-04-12 00:00:00
# 148    147  00847201904120000001164  2019-04-12 00:00:00  2019-04-12 00:00:00
# 150    148  00847201904120000001164  2019-04-12 00:00:00  2019-04-12 00:00:00
# 151    149  00847201904120000001164  2019-04-12 00:00:00  2019-04-12 00:00:00
# 152    150  00847201904120000001164  2019-04-12 00:00:00  2019-04-12 00:00:00
#
# ...

# %%
df.reset_index()
# Out:
#        index Sr No.      Reference No  (URN)         Journal Date  \
# 0          0      1  00001201904120000001166  2019-04-12 00:00:00
# 1          1      2  00001201904120000001166  2019-04-12 00:00:00
# 2          2      3  00001201904120000001166  2019-04-12 00:00:00
# 3          3      4  00001201904120000001166  2019-04-12 00:00:00
# 4          4      5  00001201904120000001166  2019-04-12 00:00:00
# ...      ...    ...                      ...                  ...
# 18866  19251  18867  00001202401110000003729  2024-01-11 00:00:00
# 18867  19252  18868  00001202401110000003729  2024-01-11 00:00:00
# 18868  19253  18869  00001202401110000003729  2024-01-11 00:00:00
# 18869  19254  18870  00001202401110000003729  2024-01-11 00:00:00
# 18870  19255  18871  00001202401110000003729  2024-01-11 00:00:00
#
#          Date of\nPurchase       Date of Expiry  \
# 0      2019-04-12 00:00:00  2019-04-26 00:00:00
# 1      2019-04-12 00:00:00  2019-04-26 00:00:00
# ...

# %%
df.head()
# Out:
#   Sr No.      Reference No  (URN)         Journal Date    Date of\nPurchase  \
# 0      1  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 1      2  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 2      3  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 3      4  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 4      5  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
#
#         Date of Expiry Name of the Purchaser Prefix Bond\nNumber  \
# 0  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11448
# 1  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11447
# 2  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11441
# 3  2019-04-26 00:00:00   A B C INDIA LIMITED     OL         1113
# 4  2019-04-26 00:00:00   A B C INDIA LIMITED     OL         1118
#
#   Denominations Issue Branch Code Issue Teller Status
# 0     10,00,000                 1      5899230   Paid
# ...

# %%
df.shape
# Out:
# (18871, 12)

# %%
# Convert 'Bond\nNumber' column to string data type
df['Bond\nNumber'] = df['Bond\nNumber'].astype(str)

# %%
# Merge the 'Prefix' and 'Bond\nNumber' columns into a new column 'FullBondNumber'
df['FullBondNumber'] = df['Prefix'] + df['Bond\nNumber']

# %%
df.head()
# Out:
#   Sr No.      Reference No  (URN)         Journal Date    Date of\nPurchase  \
# 0      1  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 1      2  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 2      3  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 3      4  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 4      5  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
#
#         Date of Expiry Name of the Purchaser Prefix Bond\nNumber  \
# 0  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11448
# 1  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11447
# 2  2019-04-26 00:00:00   A B C INDIA LIMITED     TL        11441
# 3  2019-04-26 00:00:00   A B C INDIA LIMITED     OL         1113
# 4  2019-04-26 00:00:00   A B C INDIA LIMITED     OL         1118
#
#   Denominations Issue Branch Code Issue Teller Status FullBondNumber
# ...

# %%
df.drop(columns=['Prefix','Bond\nNumber'], inplace=True)

# %%
df.head(1)
# Out:
#   Sr No.      Reference No  (URN)         Journal Date    Date of\nPurchase  \
# 0      1  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
#
#         Date of Expiry Name of the Purchaser Denominations Issue Branch Code  \
# 0  2019-04-26 00:00:00   A B C INDIA LIMITED     10,00,000                 1
#
#   Issue Teller Status FullBondNumber
# 0      5899230   Paid        TL11448

# %%
df.shape
# Out:
# (18871, 11)

# %%
# Convert 'Denominations' to string type
df['Denominations'] = df['Denominations'].astype(str)

# %%
# Replace commas only in values that contain them
df['Denominations'] = df['Denominations'].apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
df['Denominations'].unique()
# Out:
# array(['1000000', '100000', '10000000', '1000', '10000'], dtype=object)

# %%
df['Denominations'].value_counts()
# Out:
# Denominations
# 10000000    11671
# 1000000      4620
# 100000       2228
# 10000         220
# 1000          132
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Sr No.                   object
# Reference No  (URN)      object
# Journal Date             object
# Date of\nPurchase        object
# Date of Expiry           object
# Name of the Purchaser    object
# Denominations            object
# Issue Branch Code        object
# Issue Teller             object
# Status                   object
# FullBondNumber           object
# dtype: object

# %%
df['Denominations'] = df['Denominations'].astype('int64')

# %%
df.dtypes
# Out:
# Sr No.                   object
# Reference No  (URN)      object
# Journal Date             object
# Date of\nPurchase        object
# Date of Expiry           object
# Name of the Purchaser    object
# Denominations             int64
# Issue Branch Code        object
# Issue Teller             object
# Status                   object
# FullBondNumber           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sr No.                   0
# Reference No  (URN)      0
# Journal Date             0
# Date of\nPurchase        0
# Date of Expiry           0
# Name of the Purchaser    0
# Denominations            0
# Issue Branch Code        0
# Issue Teller             0
# Status                   0
# FullBondNumber           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\nPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Denominations',
#        'Issue Branch Code', 'Issue Teller', 'Status', 'FullBondNumber'],
#       dtype='object')

# %%
df['Name of the Purchaser'].nunique()
# Out:
# 1320

# %%
df['FullBondNumber'].nunique()
# Out:
# 18871

# %%
df.value_counts('Status')
# Out:
# Status
# Paid       18741
# Expired      130
# Name: count, dtype: int64

# %%
df['Denominations'].sum()
# Out:
# 121555132000

# %%
all_doner = df.groupby('Name of the Purchaser')['Denominations'].sum().sort_values(ascending=False).reset_index()

# %%
all_doner
# Out:
#                                Name of the Purchaser  Denominations
# 0                FUTURE GAMING AND HOTEL SERVICES PR    12080000000
# 1     MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED     8210000000
# 2                      QWIKSUPPLYCHAINPRIVATELIMITED     4100000000
# 3                              HALDIA ENERGY LIMITED     3770000000
# 4                                    VEDANTA LIMITED     3756500000
# ...                                              ...            ...
# 1315                  ANKUR SINGHAL S O SH  ANIL SIN           1000
# 1316                                     DAMINI NATH           1000
# 1317                              MR. SAMEER  BHATIA           1000
# 1318                                       ARAVIND S           1000
# 1319                  ADWITA FINVEST PRIVATE LIMITED           1000
#
# [1320 rows x 2 columns]

# %%
sns.barplot(df.groupby('Name of the Purchaser')['Denominations'].sum().sort_values(ascending=False).reset_index().head(15),y='Name of the Purchaser',x='Denominations',)
# Out:
# <Axes: xlabel='Denominations', ylabel='Name of the Purchaser'>

# %%
df.groupby('Name of the Purchaser')['FullBondNumber'].count().sort_values(ascending=False)
# Out:
# Name of the Purchaser
# FUTURE GAMING AND HOTEL SERVICES PR               1208
# MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED     821
# QWIKSUPPLYCHAINPRIVATELIMITED                      410
# HALDIA ENERGY LIMITED                              395
# VEDANTA LIMITED                                    386
#                                                   ...
# ARUN  KUMAR GANERIWALA                               1
# POONAM AGARWAL                                       1
# CYBER HOMES                                          1
# TADAS WIND ENERGY PVT LTD                            1
# 14 REELS PLUS LLP                                    1
# Name: FullBondNumber, Length: 1320, dtype: int64

# %% [markdown]
# ## Receiver data

# %%
receiver = pd.read_excel(r"C:\Users\sahil\Downloads\receiver.xlsx")

# %%
receiver.head(78)
# Out:
#     Sr No.  Date of\nEncashment               Name of the Political Party  \
# 0        1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1        2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2        3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3        4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4        5  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ..     ...                  ...                                       ...
# 73      73  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 74      74  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 75  Sr No.  Date of\nEncashment               Name of the Political Party
# 76      75  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 77      76  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
#
#     Account no. of\nPolitical Party  Prefix  Bond\nNumber  Denominations  \
# ...

# %%
receiver.shape
# Out:
# (20972, 9)

# %%
index = [x for x in range(37,20972,38)]
#print(index)

# %%
receiver.drop(index,inplace=True)

# %%
receiver.head(78)
# Out:
#    Sr No.  Date of\nEncashment               Name of the Political Party  \
# 0       1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ..    ...                  ...                                       ...
# 74     74  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 76     75  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 77     76  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 78     77  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
# 79     78  2019-04-12 00:00:00                    BHARATIYA JANATA PARTY
#
#    Account no. of\nPolitical Party Prefix Bond\nNumber Denominations  \
# ...

# %%
receiver.reset_index()
# Out:
#        index Sr No.  Date of\nEncashment  \
# 0          0      1  2019-04-12 00:00:00
# 1          1      2  2019-04-12 00:00:00
# 2          2      3  2019-04-12 00:00:00
# 3          3      4  2019-04-12 00:00:00
# 4          4      5  2019-04-12 00:00:00
# ...      ...    ...                  ...
# 20416  20967  20417  2024-01-24 00:00:00
# 20417  20968  20418  2024-01-24 00:00:00
# 20418  20969  20419  2024-01-24 00:00:00
# 20419  20970  20420  2024-01-24 00:00:00
# 20420  20971  20421  2024-01-24 00:00:00
#
#                     Name of the Political Party  \
# 0      ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1      ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2      ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3      ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4      ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...                                         ...
# 20416                            JANASENA PARTY
# 20417                            JANASENA PARTY
# ...

# %%
receiver.head()
# Out:
#   Sr No.  Date of\nEncashment               Name of the Political Party  \
# 0      1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1      2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2      3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3      4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4      5  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix Bond\nNumber Denominations  \
# 0                     *******5199     OC          775   1,00,00,000
# 1                     *******5199     OC         3975   1,00,00,000
# 2                     *******5199     OC         3967   1,00,00,000
# 3                     *******5199     TL        10418     10,00,000
# 4                     *******5199     TL          126     10,00,000
#
#   Pay Branch\nCode Pay Teller
# 0              800    2770121
# 1              800    2770121
# ...

# %%
receiver.shape
# Out:
# (20421, 9)

# %%
receiver.drop(columns=['Sr No.','Account no. of\nPolitical Party'], inplace=True)

# %%
receiver.head()
# Out:
#    Date of\nEncashment               Name of the Political Party Prefix  \
# 0  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     TL
# 4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     TL
#
#   Bond\nNumber Denominations Pay Branch\nCode Pay Teller
# 0          775   1,00,00,000              800    2770121
# 1         3975   1,00,00,000              800    2770121
# 2         3967   1,00,00,000              800    2770121
# 3        10418     10,00,000              800    2770121
# 4          126     10,00,000              800    2770121

# %%
# Convert 'Bond\nNumber' column to string data type
receiver['Bond\nNumber'] = receiver['Bond\nNumber'].astype(str)

# %%
# Merge both Prefix and Bond\nNumber columns
receiver['FullBondNumber'] = receiver['Prefix'] + receiver['Bond\nNumber']

# %%
receiver.head()
# Out:
#    Date of\nEncashment               Name of the Political Party Prefix  \
# 0  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     OC
# 3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     TL
# 4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM     TL
#
#   Bond\nNumber Denominations Pay Branch\nCode Pay Teller FullBondNumber
# 0          775   1,00,00,000              800    2770121          OC775
# 1         3975   1,00,00,000              800    2770121         OC3975
# 2         3967   1,00,00,000              800    2770121         OC3967
# 3        10418     10,00,000              800    2770121        TL10418
# 4          126     10,00,000              800    2770121          TL126

# %%
receiver.drop(columns=['Prefix','Bond\nNumber'], inplace=True)

# %%
receiver.head()
# Out:
#    Date of\nEncashment               Name of the Political Party  \
# 0  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Denominations Pay Branch\nCode Pay Teller FullBondNumber
# 0   1,00,00,000              800    2770121          OC775
# 1   1,00,00,000              800    2770121         OC3975
# 2   1,00,00,000              800    2770121         OC3967
# 3     10,00,000              800    2770121        TL10418
# 4     10,00,000              800    2770121          TL126

# %%
receiver['Denominations'] = receiver['Denominations'].astype(str)
receiver['Denominations'] = receiver['Denominations'].apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
receiver['Denominations'] = receiver['Denominations'].astype('int64')

# %%
receiver.dtypes
# Out:
# Date of\nEncashment            object
# Name of the Political Party    object
# Denominations                   int64
# Pay Branch\nCode               object
# Pay Teller                     object
# FullBondNumber                 object
# dtype: object

# %%
receiver.head()
# Out:
#    Date of\nEncashment               Name of the Political Party  \
# 0  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4  2019-04-12 00:00:00  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#    Denominations Pay Branch\nCode Pay Teller FullBondNumber
# 0       10000000              800    2770121          OC775
# 1       10000000              800    2770121         OC3975
# 2       10000000              800    2770121         OC3967
# 3        1000000              800    2770121        TL10418
# 4        1000000              800    2770121          TL126

# %%
receiver.groupby('Name of the Political Party')['Denominations'].sum().sort_values(ascending=False)
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                          60605111000
# ALL INDIA TRINAMOOL CONGRESS                                    16095314000
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                         14218655000
# BHARAT RASHTRA SAMITHI                                          12147099000
# BIJU JANATA DAL                                                  7755000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  6390000000
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     3370000000
# TELUGU DESAM PARTY                                               2188800000
# SHIVSENA                                                         1593814000
# RASHTRIYA JANTA DAL                                               735000000
# AAM AADMI PARTY                                                   654500000
# JANATA DAL ( SECULAR )                                            435000000
# ...

# %%
merged_data = pd.merge(df, receiver, on='FullBondNumber')

# %%
merged_data.head()
# Out:
#   Sr No.      Reference No  (URN)         Journal Date    Date of\nPurchase  \
# 0      1  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 1      2  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 2      3  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 3      4  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
# 4      5  00001201904120000001166  2019-04-12 00:00:00  2019-04-12 00:00:00
#
#         Date of Expiry Name of the Purchaser  Denominations_x  \
# 0  2019-04-26 00:00:00   A B C INDIA LIMITED          1000000
# 1  2019-04-26 00:00:00   A B C INDIA LIMITED          1000000
# 2  2019-04-26 00:00:00   A B C INDIA LIMITED          1000000
# 3  2019-04-26 00:00:00   A B C INDIA LIMITED           100000
# 4  2019-04-26 00:00:00   A B C INDIA LIMITED           100000
#
#   Issue Branch Code Issue Teller Status FullBondNumber  Date of\nEncashment  \
# ...

# %%
merged_data.shape
# Out:
# (18741, 16)

# %%
merged_data.isnull().sum()
# Out:
# Sr No.                         0
# Reference No  (URN)            0
# Journal Date                   0
# Date of\nPurchase              0
# Date of Expiry                 0
# Name of the Purchaser          0
# Denominations_x                0
# Issue Branch Code              0
# Issue Teller                   0
# Status                         0
# FullBondNumber                 0
# Date of\nEncashment            0
# Name of the Political Party    0
# Denominations_y                0
# Pay Branch\nCode               0
# Pay Teller                     0
# dtype: int64

# %%
merged_data.groupby(['Name of the Political Party','Name of the Purchaser'])['Denominations_x'].sum()
# Out:
# Name of the Political Party                                   Name of the Purchaser
# AAM AADMI PARTY                                               AAYTEE LOGISTICS PRIVATE LIMITED        3000000
#                                                               ABHISHEK KAUSHIK                        1000000
#                                                               ANAND SAKHARAM PIMPARKAR                1000000
#                                                               ARCEDGES BUILDING INDIA LLP             5000000
#                                                               ASHISH AGARWAL                          1000000
#                                                                                                        ...
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)  VEDANTA ELECTRICALS PRIVATE LIMITED    17500000
#                                                               VIPIN AGGARWAL                          2500000
# ...

# %%
merged_data.groupby(['Name of the Purchaser','Name of the Political Party'])['Denominations_x'].sum()
# Out:
# Name of the Purchaser               Name of the Political Party
# 14 REELS PLUS LLP                   BHARAT RASHTRA SAMITHI                                           10000000
# A B C INDIA LIMITED                 BHARATIYA JANATA PARTY                                            4000000
# AAKANKSHA BAHETY                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE                           1000000
# AALAYA CONSTRUCTIONS                BHARAT RASHTRA SAMITHI                                           10000000
# AARISH SOLAR POWER PRIVATE LIMITED  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     20000000
#                                                                                                       ...
# ZUVAN ENERGY PRIVATE LIMITED        YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     10000000
# ZUVAN ENERGY PVT LTD                BHARAT RASHTRA SAMITHI                                           20000000
# ...

# %%
partywise = merged_data.groupby(['Name of the Political Party','Name of the Purchaser'])['Denominations_x'].sum()

# %%
partywise.sort_values(ascending=False).head(10)
# Out:
# Name of the Political Party                                   Name of the Purchaser
# BHARATIYA JANATA PARTY                                        MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED    5190000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                               FUTURE GAMING AND HOTEL SERVICES PR               4530000000
# ALL INDIA TRINAMOOL CONGRESS                                  FUTURE GAMING AND HOTEL SERVICES PR               4350000000
# BHARATIYA JANATA PARTY                                        QWIKSUPPLYCHAINPRIVATELIMITED                     3750000000
# ALL INDIA TRINAMOOL CONGRESS                                  HALDIA ENERGY LIMITED                             2810000000
# BHARATIYA JANATA PARTY                                        VEDANTA LIMITED                                   2266500000
#                                                               BHARTI AIRTEL LIMITED                             1830000000
# ...

# %%
partywise.reset_index()
# Out:
#                             Name of the Political Party  \
# 0                                       AAM AADMI PARTY
# 1                                       AAM AADMI PARTY
# 2                                       AAM AADMI PARTY
# 3                                       AAM AADMI PARTY
# 4                                       AAM AADMI PARTY
# ...                                                 ...
# 1653  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...
# 1654  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...
# 1655  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...
# 1656  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...
# 1657  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...
#
#                     Name of the Purchaser  Denominations_x
# 0        AAYTEE LOGISTICS PRIVATE LIMITED          3000000
# 1                        ABHISHEK KAUSHIK          1000000
# 2                ANAND SAKHARAM PIMPARKAR          1000000
# ...
